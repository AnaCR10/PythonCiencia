# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Me interesa limpiar los datos de Age y Cabin
# Necesito poner como valor Age: 0 y a Cabin: CNada y Embarked : J

# %%
df_filtrado = df.fillna({"Age":0,"Cabin": 'CNada', "Embarked": 'J'})
df_filtrado.count()
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# podemos agrupar por Género/Sex

# %%
df_generos =df.groupby("Sex")
df_generos.describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std  min     25%    50%     75%    max
# Sex
# female       314.0  431.028662  256.846324  2.0  231.75  414.5  641.25  889.0
# male         577.0  454.147314  257.486139  1.0  222.00  464.0  680.00  891.0
#
#        Survived            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# Sex                        ...
# female    314.0  0.742038  ...   1.0  6.0  314.0  44.479818  57.997698  6.75
# male      577.0  0.188908  ...   0.0  5.0  577.0  25.523893  43.138263  0.00
#
#
#               25%   50%    75%       max
# Sex
# female  12.071875  23.0  55.00  512.3292
# male     7.895800  10.5  26.55  512.3292
#
# [2 rows x 56 columns]

# %% [markdown]
# Vamos a extraer los datos con información en variables
# Quiero primero, con un print, mostrar el número de pasajeros totales

# %%
pasajeros = df.shape[0] #nos da 2 valores, el primero es el nº de pasajeros por eso se pone 0 (filas y columnas)
print(f"Número de pasajeros: {pasajeros}")
# Out:
# Número de pasajeros: 891

# %% [markdown]
# vamos a sacar los supervivientes

# %%
pasajeros= df.shape[0]
supervivientes = df[df.Survived == 1]
num_survived = supervivientes.shape[0]
fallecidos = df.query("Survived == 0")
num_fallecidos = fallecidos.shape[0]
print(f" Numero de pasajeros: {pasajeros}")
print(f" Numero de supervivientes: {num_survived}")
print(f" Numero de fallecidos: {num_fallecidos}")
# Out:
#  Numero de pasajeros: 891
#  Numero de supervivientes: 342
#  Numero de fallecidos: 549

# %% [markdown]
# Almacenar los datos que tenemos en un Diccionario

# %%
data = {
    'Datos': ['pasajeros totales','Supervivientes', 'fallecidos']
         ,'Valores':[pasajeros,num_survived,num_fallecidos]
         }
df_estadistica= pd.DataFrame.from_dict(data)
df_estadistica
# Out:
#                Datos  Valores
# 0  pasajeros totales      891
# 1     Supervivientes      342
# 2         fallecidos      549

# %% [markdown]
# A continuación creamos un gráfico de Pie con el DataFrame de estadística.
# Para mostrar los datos agrupamos por la columna llamada Datos

# %%
df_grafico= df_estadistica.groupby('Datos').sum()
df_grafico.plot(kind='pie', y='Valores')
# Out:
# <Axes: ylabel='Valores'>
